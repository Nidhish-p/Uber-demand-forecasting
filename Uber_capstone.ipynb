# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df_jan=pd.read_csv('yellow_tripdata_2016-01.csv')
df_jan.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
# 2         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 4         2  2016-01-01 00:00:00   2016-01-01 00:00:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df_feb=pd.read_csv('yellow_tripdata_2016-02.csv')
df_feb.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-02-25 17:24:20   2016-02-25 17:27:20                2
# 1         2  2016-02-25 23:10:50   2016-02-25 23:31:50                2
# 2         2  2016-02-01 00:00:01   2016-02-01 00:10:52                6
# 3         1  2016-02-01 00:00:04   2016-02-01 00:05:16                1
# 4         2  2016-02-01 00:00:05   2016-02-01 00:20:59                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.70        -73.947250        40.763771           1
# 1           5.52        -73.983017        40.750992           1
# 2           1.99        -73.992340        40.758202           1
# 3           1.50        -73.981453        40.749722           1
# 4           5.60        -74.000603        40.729755           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df_mar=pd.read_csv('yellow_tripdata_2016-03.csv')
df_mar.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2016-03-01 00:00:00   2016-03-01 00:07:55                1
# 1         1  2016-03-01 00:00:00   2016-03-01 00:11:06                1
# 2         2  2016-03-01 00:00:00   2016-03-01 00:31:06                2
# 3         2  2016-03-01 00:00:00   2016-03-01 00:00:00                3
# 4         2  2016-03-01 00:00:00   2016-03-01 00:00:00                5
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           2.50        -73.976746        40.765152           1
# 1           2.90        -73.983482        40.767925           1
# 2          19.98        -73.782021        40.644810           1
# 3          10.78        -73.863419        40.769814           1
# 4          30.43        -73.971741        40.792183           3
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df=pd.concat([df_jan,df_feb,df_mar],axis=0).drop(columns=['payment_type','fare_amount',	'extra','mta_tax',	'tip_amount',	'tolls_amount',	'improvement_surcharge'])
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-01-01 00:00:00   2016-01-01 00:00:00                2
# 1         2  2016-01-01 00:00:00   2016-01-01 00:00:00                5
# 2         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 3         2  2016-01-01 00:00:00   2016-01-01 00:00:00                1
# 4         2  2016-01-01 00:00:00   2016-01-01 00:00:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.10        -73.990372        40.734695           1
# 1           4.90        -73.980782        40.729912           1
# 2          10.54        -73.984550        40.679565           1
# 3           4.75        -73.993469        40.718990           1
# 4           1.76        -73.960625        40.781330           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  total_amount
# 0                  N         -73.981842         40.732407           8.8
# ...

# %%
df.isna().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# pickup_longitude         0
# pickup_latitude          0
# RatecodeID               0
# store_and_fwd_flag       0
# dropoff_longitude        0
# dropoff_latitude         0
# total_amount             0
# dtype: int64

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  3.449986e+07     3.449986e+07   3.449986e+07      3.449986e+07
# mean   1.532576e+00     1.661700e+00   5.309408e+00     -7.283942e+01
# std    4.989377e-01     1.316154e+00   4.672575e+03      9.090656e+00
# min    1.000000e+00     0.000000e+00  -3.390584e+06     -1.616987e+02
# 25%    1.000000e+00     1.000000e+00   1.000000e+00     -7.399165e+01
# 50%    2.000000e+00     1.000000e+00   1.690000e+00     -7.398153e+01
# 75%    2.000000e+00     2.000000e+00   3.100000e+00     -7.396655e+01
# max    2.000000e+00     9.000000e+00   1.907263e+07      9.464387e+01
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     3.449986e+07  3.449986e+07       3.449986e+07      3.449986e+07
# mean      4.012605e+01  1.039150e+00      -7.290482e+01      4.016297e+01
# std       5.007832e+00  5.564537e-01       8.828348e+00      4.863875e+00
# ...

# %%
df['VendorID'].value_counts()
# Out:
# VendorID
# 2    18373797
# 1    16126062
# Name: count, dtype: int64

# %%
df['VendorID'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='VendorID'>

# %%
df['passenger_count'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='passenger_count'>

# %% [markdown]
# df['passenger_count'].value_counts()

# %%
Since, passen

# %%
plt.boxplot(df['trip_distance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27ad58eb5c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27ad5b13e00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27ad5b12b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x27ad5b182f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27ad5b18590>],
#  'means': []}

# %%
percentiles_10_to_90 = np.arange(10, 91, 10)   
values_10_to_90=np.percentile(df['trip_distance'],percentiles_10_to_90)
percentiles_91_to_100 = np.arange(91, 101, 1)
values_91_to_100=np.percentile(df['trip_distance'],percentiles_91_to_100)

# %%
for i in range(1,10,1):
    print(f'{i*10}% : {values_10_to_90[i-1]}')
# Out:
# 10% : 0.63
# 20% : 0.9
# 30% : 1.1
# 40% : 1.38
# 50% : 1.69
# 60% : 2.09
# 70% : 2.67
# 80% : 3.7
# 90% : 6.53

# %%
for i in range(1,11,1):
    print(f'{90+i}% : {values_91_to_100[i-1]}')
# Out:
# 91% : 7.15
# 92% : 7.9
# 93% : 8.7
# 94% : 9.5
# 95% : 10.3
# 96% : 11.4
# 97% : 13.45
# 98% : 16.9
# 99% : 18.56
# 100% : 19072628.8

# %%
plt.boxplot(df['total_amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27b2f5b9220>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27b2f5b9760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27b2f5b9010>],
#  'medians': [<matplotlib.lines.Line2D at 0x27b2f5b9c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27b2f5b9f40>],
#  'means': []}
